# %%
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
IMAGE_PATH="C:\\Users\\HP\\Desktop\\vs code\\python\\easy_ocr\\test1.jpeg"

# %%
reader=easyocr.Reader(['en'],gpu=False)
result=reader.readtext(IMAGE_PATH)
result
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# [([[198, 908], [252, 908], [252, 936], [198, 936]], 'THE', 0.9918584036639546),
#  ([[199, 914], [724, 914], [724, 990], [199, 990]],
#   'WAREHOUSE',
#   0.999832702633033),
#  ([[628, 972], [724, 972], [724, 1002], [628, 1002]],
#   'STORE',
#   0.9999261092249834)]

# %%
top_left=tuple(result[2][0][0])
bottom_right=tuple(result[2][0][2])
text=result[2][1]
font=cv2.FONT_HERSHEY_SIMPLEX

# %%
img=cv2.imread(IMAGE_PATH)
img= cv2.rectangle(img,top_left,bottom_right,(0,255,0),5)
img=cv2.putText(img,text,top_left,font,2,(255,255,255),2,cv2.LINE_AA)
plt.imshow(img)
plt.show()

# %%
IMAGE_PATH2="C:\\Users\\HP\\Desktop\\vs code\\python\\easy_ocr\\test3.jpeg"
reader=easyocr.Reader(['en'],gpu=False)
result=reader.readtext(IMAGE_PATH2)
for i in result:
    print(i[1])
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# TEJAS ANOVADIYA
# Newline
# Regional Sales Manager
# Gujarat
# APAC Head Quaters:
# India Office:
# HiteVision Tech Asia Pacific Co. Ltd:.
# HiteVision Tech India Private Limited
# 4F-3,No. 76, Sec.2
# Jiafong S Road,
# Room 203 , Workafella
# No. 37, TTK Road
# Zhubei City, Hsinchu Country;
# Alwarpet, Chennai-600018, India
# Taiwan-30272.
# Mobile: +91-9925153459
# Phone: +886-3-550-4768
# Phone: +91-44-4694-5513
# Website: www.hitevision com
# Email: tejas a@newline-interactive.com
# Website: wwwnewline-interactive.com
